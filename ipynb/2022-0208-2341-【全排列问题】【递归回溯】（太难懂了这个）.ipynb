# %%
from copy import copy

# %%
# 举个例子，比如你要对a,b,c三个字符进行全排列，那么它的全排列有abc,acb,bac,bca,cba,cab 这六种可能
# 当指针指向第一个元素a时，它可以是其本身a（即和自己进行交换），还可以和b，c进行交换，故有3种可能，
# 当第一个元素a确定以后，指针移向第二位置，
# 第二个位置可以和其本身b及其后的元素c进行交换，又可以形成两种排列
# 当指针指向第三个元素c的时候，这个时候其后没有元素,此时，则确定了一组排列，输出。
# 但是每次输出后要把数组恢复为原来的样子。

# %%
res = list()

def permutations(arr, position, end):
    if position == end:
        res.append(copy(arr))
    else:
        for index in range(position, end):
            arr[index], arr[position] = arr[position], arr[index]
            permutations(arr, position + 1, end)
            arr[index], arr[position] = arr[position], arr[index]

arr = [0, 1, 2, 3]
permutations(arr, 0, len(arr))

# %%
# 带输出标记

flag = 0

def permutations(arr, position, end):
    if position == end:
        res.append(copy(arr))
        print(arr)
    else:
        for index in range(position, end):
            if index!=position:
                flag = 10
            else:
                flag = 0 
            print(f"type=0, index={index}, position={position}", '='*flag)
            arr[index], arr[position] = arr[position], arr[index]
            permutations(arr, position + 1, end)
            print(f"type=1, index={index}, position={position}", "return", '='*flag)
            arr[index], arr[position] = arr[position], arr[index]

arr = [0, 1, 2, 3]
permutations(arr, 0, len(arr))
# Out:
# type=0, index=0, position=0
# type=0, index=1, position=1
# type=0, index=2, position=2
# type=0, index=3, position=3
# [0, 1, 2, 3]
# type=1, index=3, position=3 return
# type=1, index=2, position=2 return
# type=0, index=3, position=2 ==========
# type=0, index=3, position=3
# [0, 1, 3, 2]
# type=1, index=3, position=3 return
# type=1, index=3, position=2 return ==========
# type=1, index=1, position=1 return
# type=0, index=2, position=1 ==========
# type=0, index=2, position=2
# type=0, index=3, position=3
# [0, 2, 1, 3]
# type=1, index=3, position=3 return
# type=1, index=2, position=2 return
# type=0, index=3, position=2 ==========
# type=0, index=3, position=3
# [0, 2, 3, 1]
# type=1, index=3, position=3 return
# type=1, index=3, position=2 return ==========
# type=1, index=2, position=1 return ==========
# type=0, index=3, position=1 ==========
# type=0, index=2, position=2
# type=0, index=3, position=3
# [0, 3, 2, 1]
# type=1, index=3, position=3 return
# ...
